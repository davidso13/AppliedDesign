# %%
def calc_load(DL, SW, LL):
    total = 1.4 * (DL + SW) + 1.7 * LL
    return total

def calc_Mu(total, span):
    Mu = total * span * span / 8
    return Mu
print('------------ A ---------------')
print('Wu :')
print(calc_load(0.02, 0.0535, 0.05))
print(calc_load(0.02, 0.037, 0.05))
print(calc_load(0.02, 0.05, 0.05))
print(calc_load(0.02, 0.056, 0.05))
print(calc_load(0.02, 0.069, 0.05))
print(calc_load(0.02, 0.079, 0.05))
print()

print('Mu :')
print(calc_Mu(calc_load(0.02, 0.0535, 0.05), 30))
print(calc_Mu(calc_load(0.02, 0.037, 0.05), 30))
print(calc_Mu(calc_load(0.02, 0.05, 0.05), 30))
print(calc_Mu(calc_load(0.02, 0.056, 0.05), 30))
print(calc_Mu(calc_load(0.02, 0.069, 0.05), 30))
print(calc_Mu(calc_load(0.02, 0.079, 0.05), 30))

print('------------ B --------------')
print('Wu :')
print(calc_load(0.02, 0.0535, 0.05))
print(calc_load(0.02, 0.035, 0.05))
print(calc_load(0.02, 0.043, 0.05))
print(calc_load(0.02, 0.061, 0.05))
print(calc_load(0.02, 0.068, 0.05))
print(calc_load(0.02, 0.044, 0.05))
print(calc_load(0.02, 0.061, 0.05))
print(calc_load(0.02, 0.069, 0.05))
print(calc_load(0.02, 0.08, 0.05))
print()

print('Mu :')
print(calc_Mu(calc_load(0.02, 0.0535, 0.05), 30))
print(calc_Mu(calc_load(0.02, 0.035, 0.05), 30))
print(calc_Mu(calc_load(0.02, 0.043, 0.05), 30))
print(calc_Mu(calc_load(0.02, 0.061, 0.05), 30))
print(calc_Mu(calc_load(0.02, 0.068, 0.05), 30))
print(calc_Mu(calc_load(0.02, 0.044, 0.05), 30))
print(calc_Mu(calc_load(0.02, 0.061, 0.05), 30))
print(calc_Mu(calc_load(0.02, 0.069, 0.05), 30))
print(calc_Mu(calc_load(0.02, 0.08, 0.05), 30))
# Out:
# ------------ A ---------------
# Wu :
# 0.1879
# 0.1648
# 0.183
# 0.19140000000000001
# 0.2096
# 0.22360000000000002
#
# Mu :
# 21.13875
# 18.54
# 20.587500000000002
# 21.532500000000002
# 23.580000000000002
# 25.155
# ------------ B --------------
# Wu :
# 0.1879
# 0.162
# 0.17320000000000002
# 0.19840000000000002
# 0.2082
# 0.1746
# 0.19840000000000002
# 0.2096
# 0.22499999999999998
#
# Mu :
# 21.13875
# 18.225
# 19.485000000000003
# 22.320000000000004
# 23.4225
# 19.642500000000002
# 22.320000000000004
# 23.580000000000002
# 25.312499999999996
